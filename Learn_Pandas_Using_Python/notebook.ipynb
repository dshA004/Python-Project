# %%
import pandas as pd

df = pd.read_csv("orders.csv")

# %%
# print(df)
# df.head() # shows the first 5 rows of the dataframe
# df.tail() # shows the last 5 rows of the dataframe
# df.info() # shows a summary of the dataframe, including the number of non-null values and the data types of each column
# df.describe() # shows a statistical summary of the dataframe, including the mean, standard deviation, and quartiles for each numeric column
# df.columns() # shows the column names of the dataframe
#df.info() # step over the dataframe
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       40 non-null     int64
#  1   CustomerName  40 non-null     str
#  2   Product       40 non-null     str
#  3   Category      40 non-null     str
#  4   Quantity      40 non-null     int64
#  5   Price         40 non-null     float64
#  6   OrderDate     40 non-null     str
#  7   Shipped       40 non-null     str
#  8   Country       40 non-null     str
# dtypes: float64(1), int64(2), str(6)
# memory usage: 2.9 KB

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='str')

# %%
df["Country"] # shows the "Country" column of the dataframe
len(df["Country"]) # shows the number of rows in the "Country" column
set(df["Country"]) # shows unique values in the "Country" column
df[["Country", "Product"]] # create a list, get a dataframe with only the "Country" and "Product" columns
# Out:
#          Country                Product
# 0            USA                 Laptop
# 1         Canada             Headphones
# 2            UAE           Office Chair
# 3      Singapore              Desk Lamp
# 4         Mexico               Keyboard
# 5            UAE               Notebook
# 6             UK          Standing Desk
# 7    South Korea                Monitor
# 8          Italy                    Pen
# 9          Japan                  Mouse
# 10        France                 Webcam
# 11         India           File Cabinet
# 12     Australia                Stapler
# 13         Spain              USB Drive
# 14         China              Bookshelf
# 15         Egypt          Printer Paper
# 16        Poland         Wireless Mouse
# 17           USA         Desk Organizer
# 18         Japan             Calculator
# 19  Saudi Arabia             Whiteboard
# 20        Canada           Highlighters
# 21        Brazil      Bluetooth Speaker
# ...

# %%
# df.iloc[0]# shows the first row of the dataframe
# list(df.iloc[10]) # shows the 11th row of the dataframe as a list
df.iloc[10]
# Out:
# OrderID                  1011
# CustomerName    Sophie Martin
# Product                Webcam
# Category          Electronics
# Quantity                    1
# Price                    85.0
# OrderDate          2024-06-12
# Shipped                   Yes
# Country                France
# Name: 10, dtype: object
